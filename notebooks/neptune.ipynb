# %%
! pip install neptune neptune-sklearn

# %%
import pandas as pd
import numpy as np

import neptune
import neptune.integrations.sklearn as npt_utils

project = 'preethampathi2305/uber-mlops'
api_token = 'eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI2ODE4MjU3YS05NmY5LTRhZjEtYTMyYi03NjM3ODI0M2RlMzYifQ=='

# %%
uber = pd.read_csv('uber.csv')
uber.drop('Unnamed: 0', axis=1, inplace=True)

uber['pickup_year']=pd.DatetimeIndex(uber['pickup_datetime']).year
uber['pickup_month']=pd.DatetimeIndex(uber['pickup_datetime']).month
uber['pickup_day']=pd.DatetimeIndex(uber['pickup_datetime']).day
uber['pickup_hour']=pd.DatetimeIndex(uber['pickup_datetime']).hour
uber['pickup_minute']=pd.DatetimeIndex(uber['pickup_datetime']).minute
uber['pickup_second']=pd.DatetimeIndex(uber['pickup_datetime']).second

# cycling encoding for pickup_month, pickup_day, pickup_hour, pickup_minute, pickup_second

uber['pickup_month_sin'] = np.sin(uber['pickup_month']*(2.*np.pi/12))
uber['pickup_month_cos'] = np.cos(uber['pickup_month']*(2.*np.pi/12))
uber['pickup_day_sin'] = np.sin(uber['pickup_day']*(2.*np.pi/31))
uber['pickup_day_cos'] = np.cos(uber['pickup_day']*(2.*np.pi/31))
uber['pickup_hour_sin'] = np.sin(uber['pickup_hour']*(2.*np.pi/24))
uber['pickup_hour_cos'] = np.cos(uber['pickup_hour']*(2.*np.pi/24))
uber['pickup_minute_sin'] = np.sin(uber['pickup_minute']*(2.*np.pi/60))
uber['pickup_minute_cos'] = np.cos(uber['pickup_minute']*(2.*np.pi/60))
uber['pickup_second_sin'] = np.sin(uber['pickup_second']*(2.*np.pi/60))
uber['pickup_second_cos'] = np.cos(uber['pickup_second']*(2.*np.pi/60))

uber.drop('pickup_month', axis=1, inplace=True)
uber.drop('pickup_day', axis=1, inplace=True)
uber.drop('pickup_hour', axis=1, inplace=True)
uber.drop('pickup_minute', axis=1, inplace=True)
uber.drop('pickup_second', axis=1, inplace=True)

uber.drop('pickup_datetime', axis=1, inplace=True)
uber.drop('key', axis=1, inplace=True)
uber.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month_sin  \
# 0         40.723217                1         2015      5.000000e-01
# 1         40.750325                1         2009     -5.000000e-01
# 2         40.772647                1         2009     -8.660254e-01
# 3         40.803349                3         2009      1.224647e-16
# 4         40.761247                5         2014     -8.660254e-01
#
#    pickup_month_cos  pickup_day_sin  pickup_day_cos  pickup_hour_sin  \
# 0         -0.866025        0.988468        0.151428        -0.965926
# 1         -0.866025       -0.299363       -0.954139        -0.866025
# 2         -0.500000       -0.988468        0.151428        -0.707107
# 3         -1.000000       -0.848644        0.528964         0.866025
# 4         -0.500000       -0.571268        0.820763        -0.965926
#
#    pickup_hour_cos  pickup_minute_sin  pickup_minute_cos  pickup_second_sin  \
# 0         0.258819          -0.743145       6.691306e-01           0.587785
# 1         0.500000           0.406737       9.135455e-01          -0.406737
# 2         0.707107          -1.000000      -1.836970e-16           0.000000
# 3        -0.500000           0.743145      -6.691306e-01           0.809017
# 4        -0.258819          -0.978148       2.079117e-01           0.000000
#
#    pickup_second_cos
# 0           0.809017
# 1           0.913545
# 2           1.000000
# 3          -0.587785
# 4           1.000000

# %%
uber[['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']].describe()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# count     200000.000000    200000.000000      199999.000000     199999.000000
# mean         -72.527638        39.935885         -72.525292         39.923890
# std           11.437787         7.720539          13.117408          6.794829
# min        -1340.648410       -74.015515       -3356.666300       -881.985513
# 25%          -73.992065        40.734796         -73.991407         40.733823
# 50%          -73.981823        40.752592         -73.980093         40.753042
# 75%          -73.967154        40.767158         -73.963658         40.768001
# max           57.418457      1644.421482        1153.572603        872.697628

# %%
uber.drop(uber[uber['pickup_longitude']>90].index, inplace=True)
uber.drop(uber[uber['pickup_latitude']>90].index, inplace=True)
uber.drop(uber[uber['dropoff_longitude']>90].index, inplace=True)
uber.drop(uber[uber['dropoff_latitude']>90].index, inplace=True)

uber.drop(uber[uber['pickup_longitude']<-90].index, inplace=True)
uber.drop(uber[uber['pickup_latitude']<-90].index, inplace=True)
uber.drop(uber[uber['dropoff_longitude']<-90].index, inplace=True)
uber.drop(uber[uber['dropoff_latitude']<-90].index, inplace=True)

uber.drop(uber[uber['passenger_count'] > 5].index, axis=0, inplace = True)
uber.drop(uber[uber['passenger_count'] == 0].index, axis=0, inplace = True)
uber.drop(uber[uber['fare_amount'] < 2.5].index, axis=0, inplace = True)

uber.dropna(inplace=True)

uber.shape
# Out:
# (194981, 17)

# %%
uber[['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']].describe()
# Out:
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# count     194981.000000    194981.000000      194981.000000     194981.000000
# mean         -72.503114        39.920694         -72.515315         39.926626
# std           10.434251         6.087745          10.388957          6.069382
# min          -89.933333       -74.015515         -75.458979        -74.015750
# 25%          -73.992058        40.734779         -73.991400         40.733862
# 50%          -73.981828        40.752568         -73.980090         40.753045
# 75%          -73.967167        40.767145         -73.963662         40.768003
# max           40.808425        48.018760          40.831932         45.031598

# %%
uber['pickup_coords'] = list(zip(uber.pickup_latitude, uber.pickup_longitude))
uber['dropoff_coords'] = list(zip(uber.dropoff_latitude, uber.dropoff_longitude))

uber.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month_sin  \
# 0         40.723217                1         2015      5.000000e-01
# 1         40.750325                1         2009     -5.000000e-01
# 2         40.772647                1         2009     -8.660254e-01
# 3         40.803349                3         2009      1.224647e-16
# 4         40.761247                5         2014     -8.660254e-01
#
#    pickup_month_cos  pickup_day_sin  pickup_day_cos  pickup_hour_sin  \
# 0         -0.866025        0.988468        0.151428        -0.965926
# 1         -0.866025       -0.299363       -0.954139        -0.866025
# 2         -0.500000       -0.988468        0.151428        -0.707107
# 3         -1.000000       -0.848644        0.528964         0.866025
# 4         -0.500000       -0.571268        0.820763        -0.965926
#
#    pickup_hour_cos  pickup_minute_sin  pickup_minute_cos  pickup_second_sin  \
# 0         0.258819          -0.743145       6.691306e-01           0.587785
# 1         0.500000           0.406737       9.135455e-01          -0.406737
# 2         0.707107          -1.000000      -1.836970e-16           0.000000
# 3        -0.500000           0.743145      -6.691306e-01           0.809017
# 4        -0.258819          -0.978148       2.079117e-01           0.000000
#
#    pickup_second_cos                            pickup_coords  \
# 0           0.809017  (40.73835372924805, -73.99981689453125)
# 1           0.913545                  (40.728225, -73.994355)
# 2           1.000000                   (40.74077, -74.005043)
# 3          -0.587785                  (40.790844, -73.976124)
# 4           1.000000                  (40.744085, -73.925023)
#
#                          dropoff_coords
# 0  (40.72321701049805, -73.99951171875)
# 1                (40.750325, -73.99471)
# 2               (40.772647, -73.962565)
# 3               (40.803349, -73.965316)
# 4       (40.761247, -73.97308199999999)

# %%
import geopy.distance

def distance(row):
    return geopy.distance.geodesic(row['pickup_coords'], row['dropoff_coords']).miles

uber['distance'] = uber.apply(distance, axis=1)
uber.drop(uber[uber['distance'] > 130].index, axis=0, inplace = True)
uber.drop(uber[uber['distance'] == 0].index, axis=0, inplace = True)


uber.drop('pickup_coords', axis=1, inplace=True)
uber.drop('dropoff_coords', axis=1, inplace=True)

uber.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  pickup_year  pickup_month_sin  \
# 0         40.723217                1         2015      5.000000e-01
# 1         40.750325                1         2009     -5.000000e-01
# 2         40.772647                1         2009     -8.660254e-01
# 3         40.803349                3         2009      1.224647e-16
# 4         40.761247                5         2014     -8.660254e-01
#
#    pickup_month_cos  pickup_day_sin  pickup_day_cos  pickup_hour_sin  \
# 0         -0.866025        0.988468        0.151428        -0.965926
# 1         -0.866025       -0.299363       -0.954139        -0.866025
# 2         -0.500000       -0.988468        0.151428        -0.707107
# 3         -1.000000       -0.848644        0.528964         0.866025
# 4         -0.500000       -0.571268        0.820763        -0.965926
#
#    pickup_hour_cos  pickup_minute_sin  pickup_minute_cos  pickup_second_sin  \
# 0         0.258819          -0.743145       6.691306e-01           0.587785
# 1         0.500000           0.406737       9.135455e-01          -0.406737
# 2         0.707107          -1.000000      -1.836970e-16           0.000000
# 3        -0.500000           0.743145      -6.691306e-01           0.809017
# 4        -0.258819          -0.978148       2.079117e-01           0.000000
#
#    pickup_second_cos  distance
# 0           0.809017  1.044594
# 1           0.913545  1.525071
# 2           1.000000  3.131464
# 3          -0.587785  1.032372
# 4           1.000000  2.786061

# %%
from sklearn.model_selection import train_test_split

X = uber.drop(['fare_amount','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude'], axis=1)
y = uber['fare_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
train = X_train.join(y_train)
test = X_test.join(y_test)

train.to_csv('train.csv')
test.to_csv('test.csv')

TRAIN_DATASET_PATH = "train.csv"
TEST_DATASET_PATH = "test.csv"

# %%
from sklearn.ensemble import GradientBoostingRegressor

ntrees = [20,60,100]
max_depth = [2,3,4]
min_samples_leaf = [3,4,5]

for n in ntrees:
    for d in max_depth:
        for ms in min_samples_leaf:
            run = neptune.init_run(
                project=project,
                api_token=api_token
            )
            run["datasets/train"].track_files(TRAIN_DATASET_PATH)
            run["datasets/test"].track_files(TEST_DATASET_PATH)
            parameters = {
                "n_estimators": n,
                "max_depth": d,
                "min_samples_leaf":ms
            }
            run["parameters"] = parameters
            gbr = GradientBoostingRegressor(**parameters)
            gbr.fit(X_train, y_train)
            score= gbr.score(X_test,y_test)
            run["regressor/test/scores/r2_score"] = score
            run.stop()
# Out:
# <ipython-input-11-b211c7704402>:10: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-27
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 6 operations to synchronize with Neptune. Do not kill this process.
# All 6 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-27/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-28
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 6 operations to synchronize with Neptune. Do not kill this process.
# All 6 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-28/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-29
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 6 operations to synchronize with Neptune. Do not kill this process.
# All 6 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-29/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-30
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-30/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-31
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-31/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-32
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-32/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-33
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-33/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-34
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-34/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-35
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-35/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-36
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-36/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-37
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-37/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-38
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-38/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-39
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-39/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-40
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-40/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-41
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-41/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-42
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-42/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-43
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-43/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-44
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-44/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-45
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-45/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-46
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-46/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-47
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-47/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-48
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-48/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-49
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-49/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-50
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-50/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-51
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-51/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-52
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-52/metadata
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-53
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/preethampathi2305/uber-mlops/e/UB-53/metadata
